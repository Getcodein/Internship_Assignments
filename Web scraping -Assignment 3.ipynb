# %%
###=================answer1==============================

import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import  NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")
url="https://www.naukri.com/"
driver.get("https://www.amazon.in./")

# finding element for job search bar
srch_jb = driver.find_element(By.XPATH,'//input[@type="text"]')
time.sleep(3)
val=input("Enter the product you want to search for : ")
srch_jb.send_keys(val)

# clicking search button using xpath function
search_btn=driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
search_btn.click()
time.sleep(20)

#-----------------------------------answer 2-------------------------------------------------

pr_urls=[]


    
   
    #name_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
   # price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    #deli_tags=driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
    #avail_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base a-color-price"]')
    #Product_tags=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in range(0,2):
    url_tags=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for j in url_tags:
        pr_urls.append(j.get_attribute("href"))
    next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(3)
    
len(pr_urls)

# %%
brand_name=[]
name=[]
price=[]
exdelivery=[]
avail=[]
pr_link=[]

for k1 in pr_urls[:2]:
    driver.get(k1)
    time.sleep(3)
    try:
        brand_tags=driver.find_element(By.XPATH,'//div[@class="a-section a-spacing-small a-spacing-top-small"]/table/tbody/tr[1]/td[2]/span[1]')
        brand_name.append(brand_tags.text)
    except:
        brand_name.append('-')
        
    try:
        name_tags=driver.find_element(By.XPATH,'//div[@id="titleSection"]/h1/span')
        name.append(name_tags.text)
    except:
        name.append('-')
        
    try:
        price_tags=driver.find_element(By.XPATH,'//div[@class="a-section a-spacing-none a-padding-none"]/div[2]/div/div/span[1]/span[1]')
        price.append(price_tags.text)
    except:
        price.append('-')
        
        
    try:
        deli_tags=driver.find_element(By.XPATH,'//div[@id="mir-layout-DELIVERY_BLOCK-slot-PRIMARY_DELIVERY_MESSAGE_LARGE"]/span/span[1]')
        exdelivery.append(deli_tags.text)
    except:
        exdelivery.append('-')
        
    try:
        avail_tags=driver.find_element(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-micro }"]/span')
        avail.append(avail_tags.text)
    except:
        avail.append('-')
        
    try:
        pr_link.append(k1)
    except:
        pr_link.append('-')
    
        
print(len(brand_name),len(name),len(price),len(exdelivery),len(avail),len(pr_link))

# %%
#-------------------creating data frame -------------------------
Re=pd.DataFrame({})
Re['Brand_name']=brand_name
Re['Name of the product']=name
Re['Price']=price
#Re['Return/Exchange']= no data on the site
Re['Expected Delivery']=exdelivery
Re['Availability']=avail
Re['Product URL”.']=pr_link

Re

# %%
###=================answer3==============================

import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException,ElementClickInterceptedException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")


elements=["fruits",'cars','Machine learning','Guitars','Cakes']

for p in elements:
    # finding element for img for fruits search bar
    if p=='fruits':
        driver.get("https://images.google.com/")
        srch_jb = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
        srch_jb.send_keys("fruits")
        time.sleep(3)

        try:
            search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
            search_btn.click()
            time.sleep(3)
        except ElementClickInterceptedException as e:
            search_btn=driver.get("https://www.google.com/search?q=fruits&tbm=isch&sxsrf=ALiCzsYmI5h1CEVzWyfZdtFsaVQYzf5n2Q%3A1671181485470&source=hp&biw=1536&bih=746&ei=rTScY4--Gs2soASAuazADQ&iflsig=AJiK0e8AAAAAY5xCvZQbfGeUbiuw1IByHW1MdQyYzewW&ved=0ahUKEwjPyK2W5P37AhVNFogKHYAcC9gQ4dUDCAc&uact=5&oq=fruits&gs_lcp=CgNpbWcQAzIECCMQJzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMgsIABCABBCxAxCDAToFCAAQgAQ6CAgAELEDEIMBUABY0wpg4w1oAHAAeAGAAeECiAG-CZIBBzAuNC4xLjGYAQCgAQGqAQtnd3Mtd2l6LWltZw&sclient=img")

        img=[]
        title_tags=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
        for i in title_tags[0:9]:
            t=i.get_attribute('src')
            img.append(t) 

        print("------fruits images-----------")
        print((img[:10]))
    
    if p=='cars':
        driver.get("https://images.google.com/")
        srch_jb = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
        srch_jb.send_keys("cars")
        time.sleep(3)

        try:
            search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
            search_btn.click()
            time.sleep(3)
        except ElementClickInterceptedException as e:
            search_btn=driver.get("https://www.google.com/search?q=cars&tbm=isch&ved=2ahUKEwj06LLG8f37AhVXyKACHT8YBt8Q2-cCegQIABAA&oq=cars&gs_lcp=CgNpbWcQAzIHCAAQsQMQQzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMgUIABCABDIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzoKCAAQsQMQgwEQQzoECAAQQ1C0Bli3GmChHmgAcAB4AIABwgGIAfUMkgEEMC4xMJgBAKABAaoBC2d3cy13aXotaW1nsAEAwAEB&sclient=img&ei=s0KcY7TDM9eQg8UPv7CY-A0&bih=746&biw=1536")

        img=[]
        title_tags=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
        for i in title_tags[0:9]:
            t=i.get_attribute('src')
            img.append(t) 

        print("------cars images-----------")
        print((img[:10]))
        
    if p=='Machine learning':
        driver.get("https://images.google.com/")
        srch_jb = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
        srch_jb.send_keys("Machine learning")
        time.sleep(3)

        try:
            search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
            search_btn.click()
            time.sleep(3)
        except ElementClickInterceptedException as e:
            search_btn=driver.get("https://www.google.com/search?q=machine+learning&tbm=isch&ved=2ahUKEwiK3ZKl8_37AhXKntgFHWWmDhQQ2-cCegQIABAA&oq=machine+learning&gs_lcp=&sclient=img&ei=hkScY4qCPMq94t4P5cy6oAE&bih=746&biw=1536")
        img=[]
        title_tags=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
        for i in title_tags[0:9]:
            t=i.get_attribute('src')
            img.append(t) 

        print("------ML images-----------")
        print((img[:10]))
        
    if p=='guitars':
        driver.get("https://images.google.com/")
        srch_jb = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
        srch_jb.send_keys("guitars")
        time.sleep(3)

        try:
            search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
            search_btn.click()
            time.sleep(3)
        except ElementClickInterceptedException as e:
            search_btn=driver.get("https://www.google.com/search?q=guitars&tbm=isch&ved=2ahUKEwj5oYnU8_37AhWrjtgFHY2JD6MQ2-cCegQIABAA&oq=guitars&gs_lcp=CgNpbWcQAzIICAAQgAQQsQMyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQ6BwgAELEDEEM6BAgAEENQkgVYzRxgqiRoAHAAeACAAYQDiAGhEJIBBzAuOS4xLjGYAQCgAQGqAQtnd3Mtd2l6LWltZ7ABAMABAQ&sclient=img&ei=6UScY7mJGKud4t4PjZO-mAo&bih=666&biw=1036")
        
        img=[]
        title_tags=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
        for i in title_tags[0:9]:
            t=i.get_attribute('src')
            img.append(t) 

        print("------guitars images-----------")
        print((img[:10]))
        
    if p=='cakes':
        driver.get("https://images.google.com/")
        srch_jb = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
        srch_jb.send_keys("cakes")
        time.sleep(3)

        try:
            search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
            search_btn.click()
            time.sleep(3)
        except ElementClickInterceptedException as e:
            search_btn=driver.get("https://www.google.com/search?q=cakes&tbm=isch&ved=2ahUKEwidr6XY9P37AhVVk9gFHe44CU0Q2-cCegQIABAA&oq=cakes&gs_lcp=CgNpbWcQAzIICAAQgAQQsQMyCAgAEIAEELEDMggIABCABBCxAzIICAAQgAQQsQMyCAgAEIAEELEDMgsIABCABBCxAxCDATIFCAAQgAQyBQgAEIAEMgUIABCABDILCAAQgAQQsQMQgwE6BwgAELEDEEM6BAgAEEM6CAgAELEDEIMBUJcEWPAUYJIZaABwAHgEgAG2AYgBgA6SAQQwLjExmAEAoAEBqgELZ3dzLXdpei1pbWewAQDAAQE&sclient=img&ei=_kWcY524KdWm4t4P7vGk6AQ&bih=666&biw=1036")
        
        img=[]
        title_tags=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
        for i in title_tags[0:9]:
            t=i.get_attribute('src')
            img.append(t) 

        print("------cakes images-----------")
        print((img[:10]))

# %%
##------------answer 4------------------------------------
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import ElementClickInterceptedException,NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")

driver.get("https://www.flipkart.com/")


# clicking the search button
try:
    driver.get("https://www.flipkart.com/")
    # finding element for phone search bar
    srch_jb = driver.find_element(By.XPATH,'//input[@type="text"]')
    srch_jb.send_keys("Samsung Galaxy M31")

    search_button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
    search_button.click()
    time.sleep(3)
except ElementClickInterceptedException as e:
    driver.get("https://www.flipkart.com/search?q=Samsung%20Galaxy%20M31&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")
    

# creating empty lists for scraping data
b_name=[]
ph_name=[]
color=[]
ram=[]
s_rom=[]
P_cam=[]
S_cam=[]
dp_size=[]
price=[]
batter=[]
pr_url=[]


brand_tags=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
ram1_tags=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[1]')
#ph1_tags=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
camera1_tags=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[3]')
dis1_tags=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[2]')
price1_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
battery1_tags=driver.find_elements(By.XPATH,'//ul[@class="_1xgFaf"]/li[4]')
pr_url1_tags=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')

for k in brand_tags:
    m=k.text
        #time.sleep(3)
    if len(m)==0:
        k="-"
    else:
        k=m
    b_name.append(k)
        
print(len(b_name),b_name)

i=0
l=[]
for i in range(0,len(b_name)):
    b=b_name[i].split(" ")[0]
    l.append(b)

#------brand name--------
print(len(l))
#------phone name--------
ph_name=b_name
print(len(ph_name))   

mn=0
cl=[]
for mn in range(0,len(b_name)):
    u=b_name[mn].split(" ")[3:6]
    cl.append(u)

color=cl
#--------color name---------
print(len(color))  

#-------------- ram--------------------
    
for h in ram1_tags:
    o=h.text
    if len(o)==0:
        ki="-"
    else:
        ki=o
    ram.append(ki)

print(len(ram))

rw=0
rr=[]
sr=[]

for rw in range(0,len(ram)):
    ui=ram[rw].split("|")[0]
    ti=ram[rw].split("|")[1]
    rr.append(ui)
    sr.append(ti)

ram=rr
s_rom=sr

#---------print ram----------------
print(len(ram))

#--------print s_rom--------------
print(len(s_rom))


for f in camera1_tags:
    ko=f.text
    time.sleep(7)
        #time.sleep(3)
    if len(ko)==0:
        jl="-"
    else:
        jl=ko
    P_cam.append(jl)
    
rc=[]
sc=[]

print(P_cam)

for w in range(0,len(P_cam)):
    if w=='-':
        uc='-'
        tc='-'
    else:
        uc=P_cam[w].split("|")[0]
        tc=P_cam[w].split("|")[-1]
    rc.append(tc)
    sc.append(uc)

P_cam=rc
S_cam=sc
#------------primary cam,secondary cam--------------      
print(len(P_cam),len(S_cam))


#### -------------display size-------------------------------------
for f1 in dis1_tags:
    ko1=f1.text
        #time.sleep(3)
    if len(ko1)==0:
        jl1="-"
    else:
        jl1=ko1
    dp_size.append(jl1)

#-------------price size-------------------------------------
for f2 in price1_tags:
    ko2=f2.text
        #time.sleep(3)
    if len(ko2)==0:
        jl2="-"
    else:
        jl2=ko2
    price.append(jl2)
    
#-------------storage size-------------------------------------
for f3 in battery1_tags:
    ko3=f3.text
        #time.sleep(3)
    if len(ko3)==0:
        jl3="-"
    else:
        jl3=ko3
    batter.append(jl3)

#-------------producturl size-------------------------------------
for f4 in pr_url1_tags:
    ko4=f4.get_attribute("href")
        #time.sleep(3)
    if len(ko4)==0:
        jl4="-"
    else:
        jl4=ko4
    pr_url.append(jl4)
    
    
print(len(pr_url),len(batter),len(price),len(dp_size))


#-------------------creating data frame -------------------------
shop=pd.DataFrame({})
shop['BrandName']=l
shop['PhoneName']=ph_name
shop['Color']=color
shop['Ram']=ram
shop['StorageROM']=s_rom
shop['Primary Camera']=P_cam
shop['Secondary Camera']=S_cam
shop['Display_size']=dp_size
shop['Battery capacity']=batter
shop['Price']=price
shop['product URL']=pr_url


shop

# %%
##------------answer 5------------------------------------
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import ElementClickInterceptedException,NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")


# clicking the search button
try:
    driver.get("https://www.google.com/maps")
    # finding element for phone search bar
    srch_jb = driver.find_element(By.ID,"searchboxinput")
    srch_jb.send_keys("Mumbai")

    search_button=driver.find_element(By.ID,"searchbox-searchbutton")
    search_button.click()
    time.sleep(3)
except ElementClickInterceptedException as e:
    print(e)
    #driver.get("https://www.flipkart.com/search?q=Samsung%20Galaxy%20M31&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

maps_tags=driver.find_element(By.XPATH,'//meta[@itemprop="image"]')
cor=maps_tags.get_attribute("content")

#print(cor)

long=cor.split("=")[1]
long

longitude=[]
latitute=[]
latitute1=[]
long1=long.split("%")[0]
longitude=long1
latitute=long.split("%")[1].split("&")[0]
longitude
latitute1=latitute[2:]

print(longitude,",",latitute1)

# %%
#-------------answer 6 --------data information not available on the site----------

# %%
##------------answer 7------------------------------------
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import ElementClickInterceptedException,NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")


# clicking the search button
try:
    driver.get("https://www.digit.in/")
    # finding element for laptop search bar
    srch_jb = driver.find_element(By.XPATH,'//div[@class="menu"]/ul/li[3]')
    srch_jb.click()

    search_button=driver.find_element(By.XPATH,'//div[@class="Listbrand"]/ul/li[10]')
    search_button.click()
    time.sleep(3)
    
except ElementClickInterceptedException as e:
    driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")
    
# creating empty lists for scraping data
b_name=[]
processor=[]
display=[]
Os=[]
mom=[]
graphic=[]
body=[]

brand_tags=driver.find_elements(By.XPATH,'//div[@class="specfpro_details_cont"]/div/div/a/h3')
processor_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
display_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
OS_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
mom_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
graphic_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
body_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')



for k in brand_tags:
    m=k.text
    b_name.append(m)

for k1 in processor_tags:
    m1=k1.text
    processor.append(m1)
    

for k2 in display_tags:
    m2=k2.text
    display.append(m2)
    

for k3 in OS_tags:
    m3=k3.text
    Os.append(m3)

for k4 in mom_tags:
    m4=k4.text
    mom.append(m4)

for k5 in graphic_tags:
    m5=k5.text
    graphic.append(m5)
    

for k6 in body_tags:
    m6=k6.text
    body.append(m6)
    
print(len(b_name),len(processor),len(display),len(Os),len(mom),len(graphic),len(body))
    
#-------------------creating data frame -------------------------
shop=pd.DataFrame({})
shop['Brand_Name']=b_name
shop['Processor']=processor
shop['Display']=display
shop['Os']=Os
shop['Memory']=mom
shop['Graphic_processor']=graphic
shop['Body']=body



shop

# %%
##------------answer 8------------------------------------
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import ElementNotInteractableException,NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")


# clicking the search button
try:
    driver.get("https://www.forbes.com/")
    # finding element for laptop search bar
    srch_jb = driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
    srch_jb.click()
    time.sleep(3)

    search_button=driver.find_element(By.XPATH,'//div[@class="mpBfVZz3"]')
    search_button.click()
    time.sleep(3)
    
    search_button1=driver.find_element(By.XPATH,'//div[@class="xMDGnUGv"]/ul/li/a')
    search_button1.click()
    time.sleep(3)
    
except ElementNotInteractableException as e:
    driver.get("https://www.forbes.com/billionaires/")

time.sleep(3)
# creating empty lists for scraping data
#----------------------------scrapping------------------------
rank=[]
name=[]
worth=[]
coun=[]
sr=[]
Industry=[]
age=[]

name_tags=driver.find_elements(By.XPATH,'//div[@class="personName"]/div')
rank_tags=driver.find_elements(By.XPATH,'//div[@class="rank"]')
worth_tags=driver.find_elements(By.XPATH,'//div[@class="netWorth"]/div')
coun_tags=driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
sr_tags=driver.find_elements(By.XPATH,'//div[@class="source"]/div/div/span[1]')
age_tags=driver.find_elements(By.XPATH,'//div[@class="age"]')
Indus_tags=driver.find_elements(By.XPATH,'//div[@class="category"]/div')

for k in name_tags:
    m=k.text
    name.append(m)

for k1 in rank_tags:
    m1=k1.text
    rank.append(m1)
    

for k2 in worth_tags:
    m2=k2.text
    worth.append(m2)
    

for k3 in coun_tags:
    m3=k3.text
    coun.append(m3)

for k4 in sr_tags:
    m4=k4.text
    sr.append(m4)
    
for k5 in age_tags:
    m5=k5.text
    age.append(m5)

for k6 in Indus_tags:
    m6=k6.text
    Industry.append(m6)


print(len(rank),len(name),len(worth),len(coun),len(sr),len(age),len(Industry))

#-------------------creating data frame -------------------------
shop=pd.DataFrame({})
shop['Rank']=rank
shop['Name']=name
shop['Worth']=worth
shop['Age']=age
shop['Country']=coun
shop['Source']=sr
shop['Industry']=Industry

shop

# %%
##------------answer 9------------------------------------
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import ElementClickInterceptedException,NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")



# clicking the search button
try:
    driver.get("https://www.youtube.com/watch?v=CogarcpgygQ")
    # finding element for phone search bar
    time.sleep(20)
    

except ElementClickInterceptedException as e:
    driver.get("https://www.youtube.com/watch?v=CogarcpgygQ")
    time.sleep(20)

time.sleep(20)   
comments_tags=driver.find_elements(By.XPATH,'//div[@id="comment-content"]/ytd-expander[1]/div[1]/yt-formatted-string[1]')
driver.execute_script('window.scrollTo(0,390);')
upvote_tags=driver.find_elements(By.XPATH,'//div[@id="toolbar"]/span[1]')
time_tags=driver.find_elements(By.XPATH,'//div[@id="header-author"]/yt-formatted-string/a[1]')

print(len(comments_tags),len(upvote_tags),len(time_tags))


# creating empty lists for scraping data
comments=[]
upvote=[]
time=[]



for k in comments_tags:
    m=k.text
    comments.append(m)

for k1 in upvote_tags:
    m1=k1.get_attribute("aria-label")
    upvote.append(m1)
    

for k2 in time_tags:
    m2=k2.text
    time.append(m2)
    
print(len(comments_tags),len(upvote_tags),len(time_tags))



#-------------------creating data frame -------------------------
shop=pd.DataFrame({})
shop['upvotes']=upvote
shop['time']=time
shop['comments']=comments

shop

# %%
##------------answer 10------------------------------------
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import ElementNotInteractableException,NoSuchElementException
from selenium.webdriver.common.by import By
import pandas as pd
import time


#connecting to webdriver

driver=webdriver.Chrome(r"chromedriver.exe")


# clicking the search button
try:
    driver.get("https://www.hostelworld.com/")
    # finding element for laptop search bar
    srch_jb = driver.find_element(By.XPATH,'//input[@class="location-text"]')
    srch_jb.send_keys("London")
    time.sleep(1)
    
    search_btn=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
    search_btn.click()
    
    search_button1=driver.find_element(By.XPATH,'//ul[@id="predicted-search-results"]/li')
    search_button1.click()

except NoSuchElementException as e:
    driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-20&to=2022-12-23&guests=2&page=1")

time.sleep(7)

# creating empty lists for scraping data
h_name=[]
distance=[]
rating=[]
t_review=[]
o_review=[]
private_price=[]
dorm_price=[]
facilities=[]
pr_desc=[]

h_tags=driver.find_elements(By.XPATH,'//div[@class="property"]/div[1]/h2/a[1]')
distance_tags=driver.find_elements(By.XPATH,'//div[@class="property"]/div/div[1]/a/span[1]')
rating_tags=driver.find_elements(By.XPATH,'//div[@class="bottom-rating"]/a/div[1]/div[1]')
t_tags=driver.find_elements(By.XPATH,'//div[@class="bottom-rating"]/a/div[1]/div[2]/div[2]')
o_tags=driver.find_elements(By.XPATH,'//div[@class="bottom-rating"]/a/div[1]/div[2]/div/span')
private_tags=driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a/div[1]')
dorm_tags=driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a/div[2]')
facilities_tags=driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
Pr_tags=driver.find_elements(By.XPATH,'//div[@class="rating-factors prop-card-tablet rating-factors small"]')


print(len(h_tags),len(distance_tags),len(rating_tags),len(t_tags),len(o_tags),len(private_tags),len(dorm_tags),len(facilities_tags),len(Pr_tags))

for k in h_tags:
    m=k.text
    h_name.append(m)

for k1 in distance_tags:
    m1=k1.text
    distance.append(m1)
    

for k2 in rating_tags:
    m2=k2.text
    rating.append(m2)
    

for k3 in t_tags:
    m3=k3.text
    t_review.append(m3)

for k4 in o_tags:
    m4=k4.text
    o_review.append(m4)

for k5 in private_tags:
    m5=k5.text.replace('\n','|')
    private_price.append(m5)
    
for k6 in dorm_tags:
    m6=k6.text.replace('\n','|')
    dorm_price.append(m6)
    
for k7 in facilities_tags:
    m7=k7.text.replace('\n','|')
    facilities.append(m7)
    
for k8 in Pr_tags:
    m8=k8.text.replace('\n','|')
    pr_desc.append(m8)

print(len(h_name),len(distance),len(rating),len(t_review),len(o_review),len(private_price),len(dorm_price),len(facilities),len(pr_desc))

# %%
#-------------------creating data frame -------------------------
shop=pd.DataFrame({})
shop['hostel_name']=h_name
shop['distance']=distance
shop['ratings']=rating
shop['totalreviews']=t_review
shop['overallreviews']=o_review
shop['privatesfrom_price']=private_price
shop['dormsForm_price']=dorm_price
shop['facilities']=facilities
shop['property_des']=pr_desc



shop
