# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("RED_WINE_Dataset.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.head(15)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
#checking out null values in datasets (np.nan, None, NAN,others)
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#checking out the data types of each columns in datasets

df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide       int64
# total sulfur dioxide      int64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df['quality'].unique()
#so here we can see target variable is in categories . so it is classification task
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#checking whether any whitespace is present or not at my target value
df.loc[df['quality']==" "]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df.quality.unique() #we can see that the quality is categorical column, Thus it is a classification problem
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %% [raw]
# # checked no white space is peresent at any row in target value
# # if any white space then we can replace it by replace function eg:df["column_name"]= df["column name"].replace(" ",np.nan)
# # to converting it to specific data type use astype funct eg. df["column name"].astype(float)
#
# # to handle null values below can be done :
# A)if null values are very less or replace it by following:
# 2) if column is containing continous values like decimal then we can replace the null value by MEAN OR MEDIAN.
# 3) if column is containing categorical values like 0,1 or yes, no then we can replace the null value by MODE.
#
# B)if the null values are very high eg half column values are null (single column) then:
# 1) drop the null values (if we replace it by mean or median then 50% is filled with same data as using same vale - it will not help us in any way)
#
# import numpy as np
# eg: np.mean(df["column name"])
#
# fill null values: df[column_names].fillna(np.mean(df["column name"]))
#
# check values for specific row eg: df.iloc[row,:]
#
# categoricaldata
# nominal data- there is a no relation between data (no ordered data)
# ordinal data- there is order or relation between data
#
#
# sumary of describe function:
# count = if count is same for all columns then there is no missing value
# mean= if mean>median it means data is skewed in right side , median> mean then left skewed
# if 75% and max percent is huge then no outliers are there

# %%
# summary stats

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.875547             46.468418     0.996747
# std       0.047065            10.460434             32.895920     0.001887
# ...

# %% [raw]
# Key observations:
#
# 1 The mean is more than median (50th percentile) in all columns
# 2 There is a large differences in 75th percentile and max in residual sugar,
#   free sulfur dioxide, total sulfur dioxide
#
# 3 The 1 and 2 obsevations suggest that there are extreme outliers  present in  these three columns

# %%
#Data Visualizations

# %%
sns.heatmap(df.isnull()) # no null values
# Out:
# <AxesSubplot:>

# %%
To check correlation
# Out:
#   File "C:\Users\shilp\AppData\Local\Temp/ipykernel_36048/3560522512.py", line 1
#     To check correlation
#        ^
# SyntaxError: invalid syntax

# %%
dfcor=df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153791         -0.010487    -0.060885
# total sulfur dioxide      -0.113198          0.076479     0.035506
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %%
#Univariate analysis

df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['fixed acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['citric acid'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['alcohol'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['free sulfur dioxide'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (1599, 12)

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
#To check distribution of skewness

# %%
sns.distplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
#plt.figure (figure=(5*totalcol,5*totalcol))
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
# bivariate analysis
plt.scatter(df['pH'],df['quality'])

# %%
sns.pairplot(df)

# %%
plt.scatter(df['volatile acidity'],df['quality'])
plt.show()

# %% [raw]
# Here we can see a negative relation between volatile acidity and quality ,because as the volatile acidity increases quality decreases.

# %%
# Data Cleaning
df.drop('volatile acidity',axis=1,inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 0            7.4         0.00             1.9      0.076                   11
# 1            7.8         0.00             2.6      0.098                   25
# 2            7.8         0.04             2.3      0.092                   15
# 3           11.2         0.56             1.9      0.075                   17
# 4            7.4         0.00             1.9      0.076                   11
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                    34   0.9978  3.51       0.56      9.4        5
# 1                    67   0.9968  3.20       0.68      9.8        5
# 2                    54   0.9970  3.26       0.65      9.8        5
# 3                    60   0.9980  3.16       0.58      9.8        6
# 4                    34   0.9978  3.51       0.56      9.4        5

# %%
df.shape
# Out:
# (1599, 11)

# %% [raw]
# Removing the outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360     1.391472        0.453218   0.243707
# 1          0.298547     1.391472        0.043416   0.223875
# 2          0.298547     1.186070        0.169427   0.096353
# 3          1.654856     1.484154        0.453218   0.264960
# 4          0.528360     1.391472        0.453218   0.243707
# ...             ...          ...             ...        ...
# 1594       1.217796     0.980669        0.382271   0.053845
# 1595       1.390155     0.877968        0.240375   0.541259
# 1596       1.160343     0.723916        0.169427   0.243707
# 1597       1.390155     0.775267        0.382271   0.264960
# 1598       1.332702     1.021999        0.752894   0.434990
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.466240              0.379145  0.558274  1.288643
# 1                0.872555              0.624333  0.028261  0.719933
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         109,  142,  144,  147,  151,  151,  151,  151,  163,  164,  169,
#         169,  181,  226,  226,  240,  243,  244,  258,  258,  274,  281,
#         291,  324,  325,  339,  340,  347,  354,  374,  381,  391,  396,
#         396,  400,  400,  442,  442,  451,  459,  467,  480,  480,  494,
#         515,  517,  544,  554,  554,  555,  555,  557,  557,  568,  584,
#         588,  591,  595,  608,  614,  636,  639,  649,  649,  651,  652,
#         652,  652,  672,  684,  690,  692,  692,  695,  723,  730,  754,
#         776,  777,  795,  821,  832,  836,  837,  889,  899,  911,  917,
#         923,  925,  926,  982, 1017, 1018, 1043, 1051, 1051, 1071, 1074,
#        1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186,
#        1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288,
# ...

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                      11                    34  0.99780  3.51       0.56
# 1                      25                    67  0.99680  3.20       0.68
# ...

# %%
df.shape
# Out:
# (1599, 11)

# %%
df_new.shape
# Out:
# (1458, 11)

# %%
data_loss=((1599-1458)/1599)*100

# %%
data_loss
# Out:
# 8.818011257035648

# %%
x1=df_new.drop('quality',axis=1)
y1=df_new['quality']

# %%
df_new.skew()
# Out:
# fixed acidity           0.827264
# citric acid             0.297781
# residual sugar          2.457646
# chlorides               2.288587
# free sulfur dioxide     0.873162
# total sulfur dioxide    1.183539
# density                 0.061110
# pH                      0.109577
# sulphates               0.891997
# alcohol                 0.754976
# quality                 0.400875
# dtype: float64

# %%
x1['fixed acidity']=np.sqrt(x1['fixed acidity'])
sns.histplot(x1['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Count'>

# %%
#checking the skewness.
x1.skew()
# Out:
# fixed acidity           0.606194
# citric acid             0.297781
# residual sugar          2.457646
# chlorides               2.288587
# free sulfur dioxide     0.873162
# total sulfur dioxide    1.183539
# density                 0.061110
# pH                      0.109577
# sulphates               0.891997
# alcohol                 0.754976
# dtype: float64

# %%
x1
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0          2.720294         0.00             1.9      0.076
# 1          2.792848         0.00             2.6      0.098
# 2          2.792848         0.04             2.3      0.092
# 3          3.346640         0.56             1.9      0.075
# 4          2.720294         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594       2.489980         0.08             2.0      0.090
# 1595       2.428992         0.10             2.2      0.062
# 1596       2.509980         0.13             2.3      0.076
# 1597       2.428992         0.12             2.0      0.075
# 1598       2.449490         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                      11                    34  0.99780  3.51       0.56
# 1                      25                    67  0.99680  3.20       0.68
# ...

# %%
x=x1
x.shape
y=y1
y.shape
# Out:
# (1458,)

# %%
y=y.values.reshape(-1,1)
y.shape
# Out:
# (1458, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=55)

# %%
x_train.shape
# Out:
# (1020, 10)

# %%
y_train.shape
# Out:
# (1020, 1)

# %%
y_test.shape
# Out:
# (438, 1)

# %%
x_test.shape
# Out:
# (438, 10)

# %%
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
predm=mnb.predict(x_test)
print(accuracy_score(y_test,predm))
print(confusion_matrix(y_test,predm))
print(classification_report(y_test,predm))
# Out:
# 0.4452054794520548
# [[ 0  4  5  4  0]
#  [ 0 87 64 32  0]
#  [ 0 51 81 45  0]
#  [ 0  6 24 27  0]
#  [ 0  1  2  5  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        13
#            5       0.58      0.48      0.52       183
#            6       0.46      0.46      0.46       177
#            7       0.24      0.47      0.32        57
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.45       438
#    macro avg       0.26      0.28      0.26       438
# weighted avg       0.46      0.45      0.45       438

# %%
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.4908675799086758
# [[  0   1  12   0   0]
#  [  0  50 133   0   0]
#  [  0  12 165   0   0]
#  [  0   1  56   0   0]
#  [  0   1   7   0   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        13
#            5       0.77      0.27      0.40       183
#            6       0.44      0.93      0.60       177
#            7       0.00      0.00      0.00        57
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.49       438
#    macro avg       0.24      0.24      0.20       438
# weighted avg       0.50      0.49      0.41       438

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.6210045662100456
# [[  1   6   5   1   0]
#  [  6 125  44   7   1]
#  [  3  41 114  17   2]
#  [  1   6  16  32   2]
#  [  1   1   2   4   0]]
#               precision    recall  f1-score   support
#
#            4       0.08      0.08      0.08        13
#            5       0.70      0.68      0.69       183
#            6       0.63      0.64      0.64       177
#            7       0.52      0.56      0.54        57
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.62       438
#    macro avg       0.39      0.39      0.39       438
# weighted avg       0.62      0.62      0.62       438

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.4840182648401826
# [[  0   7   6   0   0]
#  [  1 120  61   1   0]
#  [  1  82  81  12   1]
#  [  1  17  28  11   0]
#  [  1   3   3   1   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        13
#            5       0.52      0.66      0.58       183
#            6       0.45      0.46      0.46       177
#            7       0.44      0.19      0.27        57
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.48       438
#    macro avg       0.28      0.26      0.26       438
# weighted avg       0.46      0.48      0.46       438

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
rf=RandomForestClassifier(n_estimators=100)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.7077625570776256
# [[  0   8   4   1   0]
#  [  0 142  40   1   0]
#  [  0  28 135  14   0]
#  [  0   2  22  33   0]
#  [  0   0   2   6   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        13
#            5       0.79      0.78      0.78       183
#            6       0.67      0.76      0.71       177
#            7       0.60      0.58      0.59        57
#            8       0.00      0.00      0.00         8
#
#     accuracy                           0.71       438
#    macro avg       0.41      0.42      0.42       438
# weighted avg       0.68      0.71      0.69       438

# %% [raw]
# We are getting 68% accuracy with Random Forest Classifier but it can be due to overfitting also so we check cross validation scores

# %%
#Cross validation
score=cross_val_score(svc,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.53082192 0.5        0.47260274 0.45704467 0.45360825]
# 0.48281551569928916

# %%
score=cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.53424658 0.58219178 0.6130137  0.5532646  0.56701031]
# 0.5699453937767736

# %%
score=cross_val_score(dtc,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.40410959 0.43835616 0.52054795 0.43298969 0.49140893]
# 0.457482464811938

# %%
score=cross_val_score(knn,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.44863014 0.49315068 0.48972603 0.38831615 0.40893471]
# 0.4457515416843195

# %%
score=cross_val_score(mnb,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.5        0.48630137 0.46232877 0.37457045 0.40549828]
# 0.44573977310172763

# %% [raw]
# Here we can see Minimum difference in accuracy and cross validation is for Support vector classifier

# %%
Hyper parameter Tunning

# %%
from sklearn import svm, datasets

from sklearn.model_selection import GridSearchCV
df=pd.read_csv("RED_WINE_Dataset.csv")
parameters={'kernel':['linear','poly'],'C':[1,10]}
svc=svm.SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x_train,y_train)
clf
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10], 'kernel': ['linear', 'poly']})

# %%
print(clf.best_params_)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
sv=svm.SVC(kernel='linear',C=1)
sv.fit(x_train,y_train)
t=sv.score(x_train,y_train)
print(t,2)
# Out:
# 0.5705882352941176 2

# %% [raw]
# # So SVC is the best model

# %%
#saving the best model
import joblib

joblib.dump(svc,'svcfile.obj')

svc_from_joblib=joblib.load('svcfile.obj')
